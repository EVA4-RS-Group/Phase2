# %% [markdown]
# <a href="https://colab.research.google.com/github/EVA4-RS-Group/Phase2/blob/master/S6/S6Trail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ls
# Out:
# drive/  sample_data/

# %%
# !ls 'drive/My Drive/img_a/img_align_celeba' | wc -l
# Out:
# 19800

# %%
# !unzip 'drive/My Drive/img_a/raw_images-20200911T043927Z-001.zip'
# Out:
# Archive:  drive/My Drive/img_a/raw_images-20200911T043927Z-001.zip
#   inflating: raw_images/figo-exterior-right-front-three-quarter-151687.jpeg
#   inflating: raw_images/renault-city-k-ze-front-view0.jpeg
#   inflating: raw_images/marutisuzuki-ignis-right-front-three-quarter3.jpeg
#   inflating: raw_images/Jeep-Compass-Exterior-103917.jpeg
#   inflating: raw_images/Jeep-Grand-Cherokee-Right-Front-Three-Quarter-79395.jpeg
#   inflating: raw_images/Maruti-Suzuki-Celerio-X-Right-Front-Three-Quarter-153971.jpeg
#   inflating: raw_images/triber-exterior-right-front-three-quarter-168562.jpeg
#   inflating: raw_images/Ford-EcoSport-Right-Front-Three-Quarter-159249.jpeg
#   inflating: raw_images/ciaz-exterior-right-front-three-quarter.jpeg
#   inflating: raw_images/duster-exterior-right-front-three-quarter-2.jpeg
#   inflating: raw_images/ertiga-exterior-right-front-three-quarter-141878.jpeg
#   inflating: raw_images/freestyle-exterior-right-front-three-quarter.jpeg
#   inflating: raw_images/kwid-exterior-right-front-three-quarter.jpeg
#   inflating: raw_images/s-presso-exterior-right-front-three-quarter-171852.jpeg
#   inflating: raw_images/Tesla-Model-3-Exterior-169923.jpeg
#   inflating: raw_images/Jeep-Wrangler-Right-Front-Three-Quarter-165896.jpeg
#   inflating: raw_images/marutisuzuki-jimny-left-side-view0.jpeg
#   inflating: raw_images/marutisuzuki-vitara-brezza-right-front-three-quarter3.jpeg
#   inflating: raw_images/Maruti-Suzuki-XL6-Exterior-165499.jpeg
#   inflating: raw_images/s-cross-petrol-exterior-right-front-three-quarter.jpeg
#   inflating: raw_images/celerio-exterior-right-front-three-quarter.jpeg
#   inflating: raw_images/eeco-exterior-right-front-three-quarter-14.jpeg
#   inflating: raw_images/Maruti-Suzuki-Baleno-Right-Front-Three-Quarter-147420.jpeg
#   inflating: raw_images/aspire-exterior-right-front-three-quarter.jpeg
#   inflating: raw_images/endeavour-exterior-right-front-three-quarter-149470.jpeg
#   inflating: raw_images/Hyundai-Grand-i10-NIOS-Exterior-165495.jpeg
#   inflating: raw_images/Maserati-GranTurismo-Exterior-138060.jpeg
#   inflating: raw_images/aura-exterior-right-front-three-quarter-53.jpeg
#   inflating: raw_images/Skoda-Superb-Facelift-Exterior-173376.jpeg
#   inflating: raw_images/Jaguar-IPace-Exterior-170105.jpeg
#   inflating: raw_images/Lexus-NX-Exterior-115308.jpeg
#   inflating: raw_images/Mitsubishi-Pajero-Sport-Right-Front-Three-Quarter-52939_ol.jpeg
#   inflating: raw_images/Lexus-LS-Exterior-116781.jpeg
#   inflating: raw_images/Fiat-Abarth-Punto-Exterior-Door-Handles-108927.jpeg
#   inflating: raw_images/skoda-karoq-right-front-three-quarter6.jpeg
#   inflating: raw_images/Mitsubishi-Outlander-Exterior-130062.jpeg
#   inflating: raw_images/lexus-lc-500h-right-front-three-quarter10.jpeg
#   inflating: raw_images/jaguar-xe-front-right-three-quarter-7.jpeg
#   inflating: raw_images/Jaguar-XF-Right-Front-Three-Quarter-80407.jpeg
#   inflating: raw_images/Fiat-Avventura-Abarth-Right-Front-Three-Quarter-55798.jpeg
#   inflating: raw_images/alturas-g4-exterior-right-front-three-quarter.jpeg
#   inflating: raw_images
#   inflating: raw_images/ramjee1-24.png
#   inflating: raw_images/ramjee-2.png
#   inflating: raw_images/4909943_indian-car-mahindra-cars-new-model-2017-transparent.png
#   inflating: raw_images/249-2499988_item-2-indian-cars.png
#   inflating: raw_images/ramjee1-23.png
#   inflating: raw_images/download.jpeg
#   inflating: raw_images/ramjee-33.png
#   inflating: raw_images/ramjee-20.png
#   inflating: raw_images/ramjee-1.png
#   inflating: raw_images/ramjee-17.png
#   inflating: raw_images/ramjee-9.png
#   inflating: raw_images/ramjee-7.png
#   inflating: raw_images/purepng.com-lexus-rc-350-silver-carcarvehicletransportlexus-961524659152pxmhz.png

# %%
# !ls '/content/raw_images' | wc -l
# Out:
# 295

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (1.6.0+cu101)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (0.7.0+cu101)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision) (7.0.0)

# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import grad

# %%
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
from torchvision import datasets
from torchvision import transforms
from torchvision.utils import save_image

# %%
import numpy as np
import datetime
import os, sys
import glob
from tqdm import tqdm

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow, imsave
# %matplotlib inline

# %%
MODEL_NAME = 'R1'
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
IMAGE_DIM = (64, 64, 3)

# %%
def tensor2img(tensor):
    #(np.transpose(tensor.detach().cpu().numpy(), [1,2,0])+1)/2.
    img = np.random.uniform(0, 200000000, (1, 64, 64, 3))
    return img

# %%
def get_sample_image(G, n_noise=100, n_samples=64):
    """
        save sample 100 images
    """
    n_rows = int(np.sqrt(n_samples))
    z = (torch.rand(size=[n_samples, n_noise])*2-1).to(DEVICE) # U[-1, 1]
    x_fake = G(z)
    x_fake = torch.cat([torch.cat([x_fake[n_rows*j+i] for i in range(n_rows)], dim=1) for j in range(n_rows)], dim=2)
    result = tensor2img(x_fake)
    return result

# %%
class ResidualBlock(nn.Module):
    def __init__(self, inplanes, planes, kernel_size=3, stride=1, downsample=None, groups=1):
        super(ResidualBlock, self).__init__()
        p = kernel_size//2
        self.conv1 = nn.Sequential(
            nn.Conv2d(inplanes, planes, kernel_size, stride=stride, padding=p),
            nn.LeakyReLU(0.2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(planes, planes, kernel_size, padding=p),
            nn.LeakyReLU(0.2)
        )
        self.proj = nn.Conv2d(inplanes, planes, 1) if inplanes != planes else None
    
    def forward(self, x):
        identity = x
        
        y = self.conv1(x)
        y = self.conv2(y)
        
        identity = identity if self.proj is None else self.proj(identity)
        y = y + identity
        return y

# %%
class Discriminator(nn.Module):
    """
        Convolutional Discriminator
    """
    def __init__(self, in_channel=1):
        super(Discriminator, self).__init__()
        self.D = nn.Sequential(
            nn.Conv2d(in_channel, 64, 3, padding=1), # (N, 64, 64, 64)
            ResidualBlock(64, 128),
            nn.AvgPool2d(3, 2, padding=1), # (N, 128, 32, 32)
            ResidualBlock(128, 256),
            nn.AvgPool2d(3, 2, padding=1), # (N, 256, 16, 16)
            ResidualBlock(256, 512),
            nn.AvgPool2d(3, 2, padding=1), # (N, 512, 8, 8)
            ResidualBlock(512, 1024),
            nn.AvgPool2d(3, 2, padding=1) # (N, 1024, 4, 4)
        )
        self.fc = nn.Linear(1024*4*4, 1) # (N, 1)
        
    def forward(self, x):
        B = x.size(0)
        h = self.D(x)
        h = h.view(B, -1)
        y = self.fc(h)
        return y

# %%
class Generator(nn.Module):
    """
        Convolutional Generator
    """
    def __init__(self, out_channel=1, n_filters=128, n_noise=512):
        super(Generator, self).__init__()
        self.fc = nn.Linear(n_noise, 1024*4*4)
        self.G = nn.Sequential(
            ResidualBlock(1024, 512),
            nn.Upsample(scale_factor=2, mode='bilinear'), # (N, 512, 8, 8)
            ResidualBlock(512, 256),
            nn.Upsample(scale_factor=2, mode='bilinear'), # (N, 256, 16, 16)
            ResidualBlock(256, 128),
            nn.Upsample(scale_factor=2, mode='bilinear'), # (N, 128, 32, 32)
            ResidualBlock(128, 64),
            nn.Upsample(scale_factor=2, mode='bilinear'), # (N, 64, 64, 64)
            ResidualBlock(64, 64),
            nn.Conv2d(64, out_channel, 3, padding=1) # (N, 3, 64, 64)
        )
        
    def forward(self, z):
        B = z.size(0)
        h = self.fc(z)
        h = h.view(B, 1024, 4, 4)
        x = self.G(h)
        return x

# %%
transform = transforms.Compose([transforms.Resize((IMAGE_DIM[0],IMAGE_DIM[1])),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=(0.5, 0.5, 0.5),
                                std=(0.5, 0.5, 0.5))
                               ]
)

# %%
dataset = datasets.ImageFolder('/content/drive/My Drive/img_a', transform=transform)

# %%
batch_size = 64
n_noise = 256

# %%
data_loader = DataLoader(dataset=dataset, batch_size=batch_size, shuffle=True, drop_last=True, num_workers=4, pin_memory=True)

# %%
D = Discriminator(in_channel=IMAGE_DIM[-1]).to(DEVICE)
G = Generator(out_channel=IMAGE_DIM[-1], n_noise=n_noise).to(DEVICE)

# %%
D_opt = torch.optim.RMSprop(D.parameters(), lr=1e-4, alpha=0.99)
G_opt = torch.optim.RMSprop(G.parameters(), lr=1e-4, alpha=0.99)

# %%
# D_scheduler = torch.optim.lr_scheduler.MultiStepLR(D_opt, milestones=[3, 10, 17], gamma=0.6)
# G_scheduler = torch.optim.lr_scheduler.MultiStepLR(G_opt, milestones=[3, 10, 17], gamma=0.6)

# %%
# criterion = nn.L1Loss()
def r1loss(inputs, label=None):
    # non-saturating loss with R1 regularization
    l = -1 if label else 1
    return F.softplus(l*inputs).mean()

# %%
max_epoch = 20
step = 0

# %%
log_term = 1000
save_term = 1000

# %%
r1_gamma = 10

# %%
steps_per_epoch = len(data_loader.dataset) // batch_size
steps_per_epoch
# Out:
# 4

# %%
if not os.path.exists('samples'):
    os.makedirs('samples')
    
if not os.path.exists('ckpt'):
    os.makedirs('ckpt')

# %%
def save_checkpoint(state, file_name='checkpoint.pth.tar'):
    torch.save(state, file_name)

# %%
for epoch in range(max_epoch):
    for idx, (images, labels) in enumerate(tqdm(data_loader, total=len(data_loader))):
        G.zero_grad()
        # Training Discriminator
        x = images.to(DEVICE)
        x.requires_grad = True
        x_outputs = D(x)
        d_real_loss = r1loss(x_outputs, True)
        # Reference >> https://github.com/rosinality/style-based-gan-pytorch/blob/a3d000e707b70d1a5fc277912dc9d7432d6e6069/train.py
        # little different with original DiracGAN
        grad_real = grad(outputs=x_outputs.sum(), inputs=x, create_graph=True)[0]
        grad_penalty = (grad_real.view(grad_real.size(0), -1).norm(2, dim=1) ** 2).mean()
        grad_penalty = 0.5*r1_gamma*grad_penalty
        D_x_loss = d_real_loss + grad_penalty

        z = (torch.rand(size=[batch_size, n_noise])*2-1).to(DEVICE)
        x_fake = G(z)
        z_outputs = D(x_fake.detach())
        D_z_loss = r1loss(z_outputs, False)
        D_loss = D_x_loss + D_z_loss
        
        D.zero_grad()
        D_loss.backward()
        D_opt.step()

        # Training Generator
        z = (torch.rand(size=[batch_size, n_noise])*2-1).to(DEVICE)
        x_fake = G(z)
        z_outputs = D(x_fake)
        G_loss = r1loss(z_outputs, True)
        
        G.zero_grad()
        G_loss.backward()
        G_opt.step()
        
        if step % save_term == 0:
            save_checkpoint({'global_step': step,
                 'D':D.state_dict(),
                 'G':G.state_dict(),
                 'd_optim': D_opt.state_dict(),
                 'g_optim' : G_opt.state_dict()},
                'ckpt/r1gan{:06d}.pth.tar'.format(step))
        
        if step % log_term == 0:
            dt = datetime.datetime.now().strftime('%H:%M:%S')
            print('Epoch: {}/{}, Step: {}, D Loss: {:.4f}, G Loss: {:.4f}, gp: {:.4f}, Time:{}'.format(epoch, max_epoch, step, D_loss.item(), G_loss.item(), grad_penalty.item(), dt))
            G.eval()
            img = get_sample_image(G, n_noise, n_samples=25)
            imsave('samples/{}_step{:02d}.jpg'.format(MODEL_NAME, step), img)
            G.train()
        
        step += 1
#     D_scheduler.step()
#     G_scheduler.step()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3121: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
#
#
#
#
#
#  25%|██▌       | 1/4 [00:04<00:13,  4.39s/it]
# Epoch: 0/20, Step: 0, D Loss: 1.3870, G Loss: 0.1506, gp: 0.0000, Time:18:48:17
#  50%|█████     | 2/4 [00:05<00:06,  3.36s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:06<00:02,  2.72s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.97s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:09,  3.02s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:04,  2.48s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.11s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:06<00:00,  1.70s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:09,  3.14s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.57s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.17s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:06<00:00,  1.74s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:09,  3.32s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.70s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.26s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.79s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:10,  3.43s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.77s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.32s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.82s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:10,  3.36s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.73s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.29s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.80s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:09,  3.07s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.52s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.14s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:06<00:00,  1.73s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:09,  3.20s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.62s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.21s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.76s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:10,  3.37s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.74s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.29s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.81s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:10,  3.37s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.74s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.30s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.82s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:09,  3.19s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.62s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.21s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.77s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:02<00:08,  2.90s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:04,  2.41s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.07s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:06<00:00,  1.70s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:09,  3.28s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.68s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.26s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.80s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:10,  3.46s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.80s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:06<00:02,  2.35s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.85s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:10,  3.36s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.74s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.30s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.82s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:09,  3.25s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.66s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.24s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.79s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:10,  3.40s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.76s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.32s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.83s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:09,  3.11s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.56s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.17s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.76s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:09,  3.03s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.51s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.14s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:06<00:00,  1.75s/it]
#
#
#
#
#
#   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
#
#
#
#
#
#  25%|██▌       | 1/4 [00:03<00:09,  3.21s/it]
#
#
#
#
#  50%|█████     | 2/4 [00:04<00:05,  2.63s/it]
#
#
#
#
#  75%|███████▌  | 3/4 [00:05<00:02,  2.23s/it]
#
#
#
#
# 100%|██████████| 4/4 [00:07<00:00,  1.79s/it]
